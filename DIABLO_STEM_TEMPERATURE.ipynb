# %%
install.packages("WallomicsData")
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")
BiocManager::install("BiocParallel")

BiocManager::install('mixOmics')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.17 (BiocManager 1.30.20), R 4.3.0 (2023-04-21)
#
# Installing package(s) 'BiocVersion', 'BiocParallel'
#
# also installing the dependencies ‘formatR’, ‘lambda.r’, ‘futile.options’, ‘futile.logger’, ‘snow’, ‘BH’
#
#
# Old packages: 'bit', 'bslib', 'cachem', 'devtools', 'digest', 'dplyr',
#   'fontawesome', 'fs', 'gargle', 'gert', 'highr', 'isoband', 'jsonlite',
#   'pkgload', 'processx', 'ps', 'rlang', 'roxygen2', 'sass', 'stringr',
#   'testthat', 'tidyverse', 'tinytex', 'vctrs', 'viridisLite', 'vroom', 'waldo',
#   'whisker', 'xfun', 'xml2', 'zip', 'boot', 'class', 'foreign', 'KernSmooth',
#   'MASS', 'nnet'
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.17 (BiocManager 1.30.20), R 4.3.0 (2023-04-21)
#
# Installing package(s) 'mixOmics'
#
# also installing the dependencies ‘RcppEigen’, ‘plyr’, ‘Rcpp’, ‘RSpectra’, ‘igraph’, ‘ellipse’, ‘corpcor’, ‘reshape2’, ‘matrixStats’, ‘rARPACK’, ‘gridExtra’, ‘ggrepel’
#
#
# Old packages: 'bit', 'bslib', 'cachem', 'devtools', 'digest', 'dplyr',
#   'fontawesome', 'fs', 'gargle', 'gert', 'highr', 'isoband', 'jsonlite',
#   'pkgload', 'processx', 'ps', 'rlang', 'roxygen2', 'sass', 'stringr',
#   'testthat', 'tidyverse', 'tinytex', 'vctrs', 'viridisLite', 'vroom', 'waldo',
#   'whisker', 'xfun', 'xml2', 'zip', 'boot', 'class', 'foreign', 'KernSmooth',
#   'MASS', 'nnet'

# %%
# Charger les packages

library(mixOmics)
# Out:
# Loading required package: MASS
#
# Loading required package: lattice
#
# Loading required package: ggplot2
#
#
# Loaded mixOmics 6.24.0
# Thank you for using mixOmics!
# Tutorials: http://mixomics.org
# Bookdown vignette: https://mixomicsteam.github.io/Bookdown
# Questions, issues: Follow the prompts at http://mixomics.org/contact-us
# Cite us:  citation('mixOmics')

# %%
install.packages("WallomicsData")
library(WallomicsData)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("glmnet")
library(glmnet)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘iterators’, ‘foreach’, ‘shape’
#
#
# Loading required package: Matrix
#
# Loaded glmnet 4.1-7

# %%
library("matrixStats")

# %%
data("Altitude_Cluster")
data("Ecotype")
data("Genetic_Cluster")
data("Metabolomics_Rosettes")
data("Metabolomics_Stems")
data("Metadata")
data("Phenomics_Rosettes")
data("Phenomics_Stems")
data("Proteomics_Rosettes_CW")
data("Proteomics_Stems_CW")
data("Transcriptomics_Rosettes")
data("Transcriptomics_Rosettes_CW")
data("Transcriptomics_Stems")
data("Transcriptomics_Stems_CW")
data("Temperature")

# %% [markdown]
# ###Exploratory Data Analysis:
# handleing missing values in each data frame using median imputation

# %%
for(i in 1:ncol(Metabolomics_Stems)){Metabolomics_Stems[,i][is.na(Metabolomics_Stems[,i])]<-median(Metabolomics_Stems[,i],na.rm=TRUE)}

for(i in 1:ncol(Phenomics_Stems)){Phenomics_Stems[,i][is.na(Phenomics_Stems[,i])]<-median(Phenomics_Stems[,i],na.rm=TRUE)}

for(i in 1:ncol(Proteomics_Stems_CW)){Proteomics_Stems_CW[,i][is.na(Proteomics_Stems_CW[,i])]<-median(Proteomics_Stems_CW[,i],na.rm=TRUE)}

for(i in 1:ncol(Transcriptomics_Stems)){Transcriptomics_Stems[,i][is.na(Transcriptomics_Stems[,i])]<-median(Transcriptomics_Stems[,i],na.rm=TRUE)}

for(i in 1:ncol(Transcriptomics_Stems_CW)){Transcriptomics_Stems_CW[,i][is.na(Transcriptomics_Stems_CW[,i])]<-median(Transcriptomics_Stems_CW[,i],na.rm=TRUE)}

# %% [markdown]
# ###handling nonzero
# cause it cause problem in diablo WITH TRANSCRIPTOMICS

# %%
my_nearZeroVar<-nearZeroVar(Transcriptomics_Stems)
#head(my_nearZeroVar$Metrics)
Transcriptomics_Stems <- Transcriptomics_Stems[,-which(colnames(Transcriptomics_Stems)%in%rownames(my_nearZeroVar$Metrics))]

# %% [markdown]
# ###Feature Selection (high dimentioanl data p>10n) For OMICs Integration ONLY ON TRANSCRIPTOMICS !!!!!
# Right now we can not integrate the OMICs data sets since at least Proteomics_Stems_CWession and methylation data are high-dimensional so we need to perform a feature selection for those two OMICs. Here we use LASSO for doing feature selection for gene Proteomics_Stems_CWession data:

# %% [markdown]
# we can not integrate the OMICs data sets since Proteomics_Rosettes_CW and Transcriptomics_Rosettes and Transcriptomics_Rosettes_CW data are high-dimensional so we need to perform a feature selection for those two OMICs. Here we use LASSO for doing feature selection

# %%
#high dim data are Proteomics_Stems_CW Transcriptomics_Stems Transcriptomics_Stems_CW 
#Proteomics_Stems_CW
lasso_fit <- cv.glmnet(as.matrix(Proteomics_Stems_CW), Temperature, family = "binomial", alpha = 1)
plot(lasso_fit)
# Out:
# plot without title

# %%
coef <- predict(lasso_fit, s = "lambda.min", type = "nonzero")
colnames(Proteomics_Stems_CW)[unlist(coef)]
# Out:
#  [1] "AT1G10640" "AT1G26560" "AT1G29670" "AT1G47128" "AT1G78040" "AT2G06850"
#  [7] "AT2G37640" "AT3G05180" "AT3G10450" "AT3G14920" "AT3G18080" "AT3G22060"
# [13] "AT4G01700" "AT4G21640" "AT4G23820" "AT5G19740" "AT5G21100" "AT5G51950"
# [19] "AT5G62210" "AT5G62350"

# %%
x=names(as.matrix(coef(lasso_fit, s = "lambda.min"))[as.matrix(coef(lasso_fit, s = "lambda.min"))[,1]!=0, 1])[-1]
y=as.numeric(as.matrix(coef(lasso_fit, s = "lambda.min"))[as.matrix(coef(lasso_fit,s = "lambda.min"))[,1]!=0, 1])[-1]

result_Proteomics_Stems_CW <- data.frame(CWP = x, SCORE =y)
result_Proteomics_Stems_CW <- result_Proteomics_Stems_CW[order(-abs(result_Proteomics_Stems_CW$SCORE)),]
print(head(result_Proteomics_Stems_CW,10))
# Out:
#          CWP     SCORE
# 19 AT5G62210 -6.695026
# 4  AT1G47128  5.592579
# 18 AT5G51950 -5.147821
# 20 AT5G62350 -4.206260
# 11 AT3G18080  3.021317
# 15 AT4G23820 -2.628068
# 3  AT1G29670 -2.575702
# 12 AT3G22060  2.537828
# 10 AT3G14920  2.531261
# 13 AT4G01700 -2.190438

# %%
print(as.character(result_Proteomics_Stems_CW$CWP))
# Out:
#  [1] "AT5G62210" "AT1G47128" "AT5G51950" "AT5G62350" "AT3G18080" "AT4G23820"
#  [7] "AT1G29670" "AT3G22060" "AT3G14920" "AT4G01700" "AT1G10640" "AT1G78040"
# [13] "AT2G06850" "AT1G26560" "AT5G19740" "AT3G05180" "AT2G37640" "AT5G21100"
# [19] "AT3G10450" "AT4G21640"

# %%
Proteomics_Stems_CW <- subset(Proteomics_Stems_CW, select = as.character(result_Proteomics_Stems_CW$CWP))

# %%
#Transcriptomics_Stems
lasso_fit <- cv.glmnet(as.matrix(Transcriptomics_Stems), Temperature, family = "binomial", alpha = 1)
plot(lasso_fit)
# Out:
# plot without title

# %%
coef <- predict(lasso_fit, s = "lambda.min", type = "nonzero")
colnames(Transcriptomics_Stems)[unlist(coef)]
# Out:
#  [1] "AT1G06360" "AT1G64980" "AT1G69620" "AT1G78080" "AT2G39850" "AT3G14290"
#  [7] "AT3G24100" "AT3G24420" "AT3G29230" "AT4G00490" "AT4G12030" "AT5G45920"

# %%
x=names(as.matrix(coef(lasso_fit, s = "lambda.min"))[as.matrix(coef(lasso_fit, s = "lambda.min"))[,1]!=0, 1])[-1]
y=as.numeric(as.matrix(coef(lasso_fit, s = "lambda.min"))[as.matrix(coef(lasso_fit,s = "lambda.min"))[,1]!=0, 1])[-1]

result_Transcriptomics_Stems <- data.frame(RNA = x, SCORE =y)
result_Transcriptomics_Stems <- result_Transcriptomics_Stems[order(-abs(result_Transcriptomics_Stems$SCORE)),]
print(head(result_Transcriptomics_Stems,10))
# Out:
#          RNA       SCORE
# 9  AT3G29230  0.45009239
# 8  AT3G24420 -0.15226966
# 11 AT4G12030 -0.11712398
# 12 AT5G45920 -0.09430008
# 7  AT3G24100  0.08913414
# 5  AT2G39850  0.06041971
# 2  AT1G64980 -0.02612044
# 1  AT1G06360 -0.02355153
# 10 AT4G00490 -0.01735488
# 6  AT3G14290 -0.01502881

# %%
Transcriptomics_Stems <- subset(Transcriptomics_Stems, select = as.character(result_Transcriptomics_Stems$RNA))

# %%
#Transcriptomics_Stems_CW
lasso_fit <- cv.glmnet(as.matrix(Transcriptomics_Stems_CW), Temperature, family = "binomial", alpha = 1)
plot(lasso_fit)
# Out:
# plot without title

# %%
coef <- predict(lasso_fit, s = "lambda.min", type = "nonzero")
colnames(Transcriptomics_Stems_CW)[unlist(coef)]
# Out:
#  [1] "AT1G09010" "AT1G27950" "AT1G55265" "AT2G33530" "AT2G39850" "AT3G05730"
#  [7] "AT3G06035" "AT4G00860" "AT4G21585" "AT4G30290" "AT5G45280"

# %%
x=names(as.matrix(coef(lasso_fit, s = "lambda.min"))[as.matrix(coef(lasso_fit, s = "lambda.min"))[,1]!=0, 1])[-1]
y=as.numeric(as.matrix(coef(lasso_fit, s = "lambda.min"))[as.matrix(coef(lasso_fit,s = "lambda.min"))[,1]!=0, 1])[-1]

result_Transcriptomics_Stems_CW <- data.frame(RNA_CW= x, SCORE =y)
result_Transcriptomics_Stems_CW <- result_Transcriptomics_Stems_CW[order(-abs(result_Transcriptomics_Stems_CW$SCORE)),]
print(head(result_Transcriptomics_Stems_CW,10))
# Out:
#       RNA_CW        SCORE
# 9  AT4G21585 -0.783648180
# 1  AT1G09010  0.214146101
# 5  AT2G39850  0.091674838
# 11 AT5G45280 -0.088232945
# 3  AT1G55265 -0.036282109
# 7  AT3G06035 -0.025154497
# 6  AT3G05730 -0.018638476
# 2  AT1G27950 -0.008098939
# 8  AT4G00860 -0.007724072
# 4  AT2G33530 -0.005895960

# %%
Transcriptomics_Stems_CW<-subset(Transcriptomics_Stems_CW, select = as.character(result_Transcriptomics_Stems_CW$RNA_CW))

# %%
dim(Transcriptomics_Stems_CW)
dim(Transcriptomics_Stems)
dim(Proteomics_Stems_CW)
# Out:
# [1] 30 11
# [1] 30 12
# [1] 30 20

# %% [markdown]
# We can see that we dramatically decreased the number of dimensions / features in the chosen  data sets. Now we can proceed with OMICs integration via PLS-DA algorithm (DIABLO).

# %% [markdown]
# ###OMICS INTEGRATION ANALYSIS

# %% [markdown]
# We can see that we dramatically decreased the number of dimensions / features in the chosen  data sets. Now we can proceed with OMICs integration via PLS-DA algorithm (DIABLO).

# %% [markdown]
# Now we will start integrating the 5 OMICs.
#
# For this purpose we will concatenate them into X matrix and use the TEMPERATURE as Y variable, so it is a typical Machine Learning setup: y=f(x), where x is the input, y is the class labels of individuals and the f-function is learnt from the data. Note that the f-function is a-priori linear for PLS-DA and non-linear.

# %%
data<-list(Proteomics_CW=Proteomics_Stems_CW,Transcriptomics=Transcriptomics_Stems,Transcriptomics_CW=Transcriptomics_Stems_CW,Phenomics=Phenomics_Stems,Metabolomics=Metabolomics_Stems)
names(data)
lapply(data, dim)
# Out:
# [1] "Proteomics_CW"      "Transcriptomics"    "Transcriptomics_CW"
# [4] "Phenomics"          "Metabolomics"
# $Proteomics_CW
# [1] 30 20
#
# $Transcriptomics
# [1] 30 12
#
# $Transcriptomics_CW
# [1] 30 11
#
# $Phenomics
# [1] 30  4
#
# $Metabolomics
# [1] 30  6

# %% [markdown]
# First, we fit a DIABLO model without variable selection to assess the global performance and choose the number of components for the final DIABLO model. The function “perf” will perform M-fold cross validation (number of folds is specified by “folds” parameter) repeated “nrepeat” times. The design matrix sets expected correlation between the OMICs. The values may range between 0 (no correlation) to 1 (strong correlation), the design can be chosen based on prior knowledge inferred by e.g. MOFA (see Unsupervised OMICs integration session). Here due to the lack of prior knowledge we assume a strong correlation 1 between the OMICs.

# %% [markdown]
# The choice of the design can be motivated by different aspects, including:
#
# Biological apriori knowledge: Should we expect mRNA and miRNA to be highly correlated?
#
# Analytical aims: As further developed in Singh et al. (2019), a compromise needs to be achieved between a classification and prediction task, and extracting the correlation structure of the data sets. A full design with weights = 1 will favour the latter, but at the expense of classification accuracy, whereas a design with small weights will lead to a highly predictive signature. This pertains to the complexity of the analytical task involved as several constraints are included in the optimisation procedure. For example, here we choose a 0.1 weighted model as we are interested in predicting test samples later in this case study.

# %%
#we can also use correlation between paires to get an idea on design matrix
#res1.pls.tcga <- pls(X$mRNA, X$protein, ncomp = 1)
#cor(res1.pls.tcga$variates$X, res1.pls.tcga$variates$Y)
#
#res2.pls.tcga <- pls(X$mRNA, X$miRNA, ncomp = 1)
#cor(res2.pls.tcga$variates$X, res2.pls.tcga$variates$Y)
#
#res3.pls.tcga <- pls(X$protein, X$miRNA, ncomp = 1)
#cor(res3.pls.tcga$variates$X, res3.pls.tcga$variates$Y)

# %%
BPPARAM <- BiocParallel::SnowParam(workers = parallel::detectCores()-1)

# %%
design=matrix(0.1,ncol=length(data),nrow=length(data),dimnames=list(names(data),names(data)))
diag(design)=0
design
# Out:
#                    Proteomics_CW Transcriptomics Transcriptomics_CW Phenomics
# Proteomics_CW      0.0           0.1             0.1                0.1
# Transcriptomics    0.1           0.0             0.1                0.1
# Transcriptomics_CW 0.1           0.1             0.0                0.1
# Phenomics          0.1           0.1             0.1                0.0
# Metabolomics       0.1           0.1             0.1                0.1
#                    Metabolomics
# Proteomics_CW      0.1
# Transcriptomics    0.1
# Transcriptomics_CW 0.1
# Phenomics          0.1
# Metabolomics       0.0

# %%
splsda.res = block.splsda(X = data, Y = Temperature, ncomp = 4, design = design)
# Out:
# Design matrix has changed to include Y; each block will be
#             linked to Y.

# %%
perf.diablo = perf(splsda.res, validation = 'Mfold', folds = 10, nrepeat = 10, progressBar=FALSE, BPPARAM = BPPARAM)
perf.diablo$class
# Out:
# $nrep1
# $nrep1$Proteomics_CW
# $nrep1$Proteomics_CW$max.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
# $nrep1$Proteomics_CW$centroids.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
# $nrep1$Proteomics_CW$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
#
# $nrep1$Transcriptomics
# $nrep1$Transcriptomics$max.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
# $nrep1$Transcriptomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
# $nrep1$Transcriptomics$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
#
# $nrep1$Transcriptomics_CW
# $nrep1$Transcriptomics_CW$max.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
# $nrep1$Transcriptomics_CW$centroids.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
# $nrep1$Transcriptomics_CW$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
#
# $nrep1$Phenomics
# $nrep1$Phenomics$max.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "22"  "22"  "22"
# Col.15.3  "15"  "22"  "22"  "22"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "15"  "15"  "15"
# Hosp.22.2 "15"  "15"  "15"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "15"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "15"  "15"  "15"
# Hern.22.1 "15"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
#
# $nrep1$Phenomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "22"  "22"  "22"
# Col.15.3  "15"  "22"  "22"  "22"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "15"  "15"  "15"
# Hosp.22.2 "22"  "15"  "15"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "15"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "15"  "15"
# Hern.22.1 "15"  "15"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
#
# $nrep1$Phenomics$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "22"  "22"  "22"
# Col.15.3  "15"  "22"  "22"  "22"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "15"  "15"  "15"
# Hosp.22.2 "22"  "15"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "15"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "15"  "15"  "15"
# Hern.22.1 "15"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
#
#
# $nrep1$Metabolomics
# $nrep1$Metabolomics$max.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "22"  "22"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "22"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "15"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
# $nrep1$Metabolomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "22"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
# $nrep1$Metabolomics$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Col.15.1  "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "22"  "22"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "22"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "15"
# Hern.15.1 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
#
#
#
# $nrep2
# $nrep2$Proteomics_CW
# $nrep2$Proteomics_CW$max.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
# $nrep2$Proteomics_CW$centroids.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
# $nrep2$Proteomics_CW$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
#
# $nrep2$Transcriptomics
# $nrep2$Transcriptomics$max.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
# $nrep2$Transcriptomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
# $nrep2$Transcriptomics$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
#
# $nrep2$Transcriptomics_CW
# $nrep2$Transcriptomics_CW$max.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
# $nrep2$Transcriptomics_CW$centroids.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
# $nrep2$Transcriptomics_CW$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
#
# $nrep2$Phenomics
# $nrep2$Phenomics$max.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "15"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "15"  "15"
# Col.15.1  "15"  "22"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "15"  "15"  "15"
# Roch.22.3 "22"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "22"  "22"  "22"  "22"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "15"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
# $nrep2$Phenomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "15"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "22"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "15"  "15"  "15"
# Roch.22.3 "22"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "22"  "22"  "22"  "22"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "15"  "15"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
# $nrep2$Phenomics$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "15"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "15"  "15"
# Col.15.1  "15"  "22"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "22"  "15"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "15"  "15"  "15"
# Roch.22.3 "22"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "22"  "22"  "22"  "22"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "15"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
#
# $nrep2$Metabolomics
# $nrep2$Metabolomics$max.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "22"  "22"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "15"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "22"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "22"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
# $nrep2$Metabolomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "22"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "22"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
# $nrep2$Metabolomics$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "22"  "22"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.2 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Col.22.1  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.15.2 "22"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.22.1 "22"  "22"  "22"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.15.3 "22"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
#
#
#
# $nrep3
# $nrep3$Proteomics_CW
# $nrep3$Proteomics_CW$max.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
# $nrep3$Proteomics_CW$centroids.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
# $nrep3$Proteomics_CW$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
#
# $nrep3$Transcriptomics
# $nrep3$Transcriptomics$max.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
# $nrep3$Transcriptomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
# $nrep3$Transcriptomics$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
#
# $nrep3$Transcriptomics_CW
# $nrep3$Transcriptomics_CW$max.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
# $nrep3$Transcriptomics_CW$centroids.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
# $nrep3$Transcriptomics_CW$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "15"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
#
# $nrep3$Phenomics
# $nrep3$Phenomics$max.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "22"  "22"  "22"  "22"
# Hern.22.3 "15"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "15"  "15"  "22"  "22"
# Col.15.1  "15"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
# $nrep3$Phenomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "22"  "22"  "22"  "22"
# Hern.22.3 "15"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "15"  "15"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
# $nrep3$Phenomics$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "22"  "22"  "22"  "22"
# Hern.22.3 "15"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "15"  "15"  "15"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "15"  "15"  "22"  "22"
# Col.15.1  "15"  "22"  "22"  "22"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
#
# $nrep3$Metabolomics
# $nrep3$Metabolomics$max.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "22"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "15"  "15"  "15"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.15.3 "22"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "22"  "15"
# Hern.22.1 "22"  "22"  "22"  "15"
# Col.15.1  "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
#
# $nrep3$Metabolomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Hern.15.2 "22"  "15"  "15"  "15"
# Hern.22.3 "22"  "22"  "22"  "22"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Roch.22.3 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.15.2 "15"  "15"  "15"  "15"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
# Roch.22.1 "22"  "22"  "22"  "22"
# Roch.15.3 "22"  "15"  "15"  "15"
# Grip.22.3 "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# ...
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
#
# $nrep10$Proteomics_CW$centroids.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
#
# $nrep10$Proteomics_CW$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
#
#
# $nrep10$Transcriptomics
# $nrep10$Transcriptomics$max.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
#
# $nrep10$Transcriptomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
#
# $nrep10$Transcriptomics$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
#
#
# $nrep10$Transcriptomics_CW
# $nrep10$Transcriptomics_CW$max.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
#
# $nrep10$Transcriptomics_CW$centroids.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
#
# $nrep10$Transcriptomics_CW$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "15"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "15"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
#
#
# $nrep10$Phenomics
# $nrep10$Phenomics$max.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "15"  "15"  "15"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "22"  "15"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "15"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "15"  "15"  "15"
# Hern.15.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "15"  "22"  "22"  "22"
# Col.15.1  "15"  "22"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
#
# $nrep10$Phenomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "15"  "15"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "22"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "15"  "15"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "15"  "15"  "15"
# Hern.15.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "15"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
#
# $nrep10$Phenomics$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "15"  "15"  "15"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "22"  "15"  "22"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "15"  "15"  "15"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "15"  "22"  "22"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "15"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "15"  "15"  "15"
# Hern.15.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "15"  "22"  "22"  "22"
# Col.15.1  "15"  "22"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "15"  "15"  "15"  "15"
#
#
# $nrep10$Metabolomics
# $nrep10$Metabolomics$max.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "22"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
#
# $nrep10$Metabolomics$centroids.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "15"  "15"  "15"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "22"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "22"  "22"  "22"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"
#
# $nrep10$Metabolomics$mahalanobis.dist
#           comp1 comp2 comp3 comp4
# Grip.15.2 "15"  "15"  "15"  "15"
# Col.22.1  "22"  "22"  "22"  "22"
# Grip.22.3 "22"  "22"  "22"  "22"
# Roch.15.3 "15"  "15"  "15"  "15"
# Grip.15.3 "15"  "15"  "15"  "15"
# Roch.22.2 "22"  "22"  "22"  "22"
# Hern.15.1 "15"  "15"  "15"  "15"
# Col.22.3  "22"  "22"  "22"  "22"
# Col.15.3  "15"  "15"  "15"  "15"
# Hosp.22.2 "22"  "22"  "22"  "22"
# Hosp.15.2 "15"  "15"  "15"  "15"
# Roch.22.1 "22"  "22"  "22"  "22"
# Grip.22.2 "22"  "22"  "22"  "22"
# Hosp.15.1 "15"  "22"  "22"  "22"
# Hosp.15.3 "15"  "15"  "15"  "15"
# Col.22.2  "22"  "22"  "22"  "22"
# Hosp.22.3 "22"  "22"  "22"  "22"
# Hern.15.2 "22"  "15"  "15"  "15"
# Roch.15.1 "15"  "15"  "15"  "15"
# Hern.22.1 "22"  "22"  "22"  "15"
# Col.15.2  "15"  "15"  "15"  "15"
# Hosp.22.1 "22"  "22"  "22"  "22"
# Roch.22.3 "22"  "22"  "22"  "22"
# Hern.15.3 "22"  "15"  "15"  "15"
# Grip.15.1 "15"  "15"  "15"  "15"
# Grip.22.1 "22"  "22"  "22"  "22"
# Hern.22.3 "22"  "22"  "22"  "22"
# Col.15.1  "15"  "15"  "15"  "15"
# Roch.15.2 "15"  "15"  "15"  "15"
# Hern.22.2 "22"  "22"  "22"  "22"

# %%
plot(perf.diablo)
# Out:
# plot without title

# %% [markdown]
# Here all BER (balanced error rate) distances seem to reach their minimum / plateau at ncomp=1, and do not seem to change further. Therefore, we will use ncomp=2 as an optimal number of PLS components to keep in the further downstream analysis because the method used only accepts 2 comp. In the BER figure, different colors correspond to different distances between the  samples projected on the reference during the cross-validation procedure. In every cross-validation iteration we decide which sample belongs to which Temperature , and the distance measuring the proximity to a cluster can be max.dist, mahalanobis.dist and centroids.dist. After a test sample has been assigned to one of the reference clusters, and got a predicted label, it is validated against its true label, and the accuracy (or error rate in this case) demonstrate how generalizable the model is.
#
# After we have selected the optimal number of PLS components, let us now perform tuning of the model which implies selecting most informative variables in all layers of the data. For this purpose, we will again need to provide the design matrix which shows a-priori correlation between the phenotype of interest and the OMICs. We assumed a weak correlation, but one can in principle play with this parameter and find out how it influences the final result. Further, we will concentrate on the first two PLS components based on the output of “perf”-function above.

# %%
# set the optimal ncomp value
ncomp = perf.diablo$choice.ncomp$WeightedVote["Overall.BER", "centroids.dist"] 
# show the optimal choice for ncomp for each dist metric
perf.diablo$choice.ncomp$WeightedVote
# Out:
#             max.dist centroids.dist mahalanobis.dist
# Overall.ER  1        1              1
# Overall.BER 1        1              1

# %%
#this takes about 23 min to run that's why we chose smalltest keep 
test.keepX=list(
  "Proteomics_CW"=c(1:5),
  "Transcriptomics_CW"=c(1:5),
  "Transcriptomics"=c(1:5),
  "Phenomics"=c(1:5),
  "Metabolomics"=c(1:5)
)
ptm<-proc.time()
tune.omics=tune.block.splsda(X=data,Y=Temperature,ncomp=ncomp,test.keepX=test.keepX,design=design,progressBar=FALSE,validation="Mfold",folds=2,nrepeat=5,near.zero.var=FALSE,dist = "mahalanobis.dist",BPPARAM = BPPARAM)
# Out:
# Design matrix has changed to include Y; each block will be
#             linked to Y.
#
#
# You have provided a sequence of keepX of length: 5 for block Proteomics_CW and 5 for block Transcriptomics_CW and 5 for block Transcriptomics and 5 for block Phenomics and 5 for block Metabolomics.
# This results in 3125 models being fitted for each component and each nrepeat, this may take some time to run, be patient!

# %%
my_time<-proc.time()-ptm
print(paste0("Thus it takes ",as.numeric(my_time["elapsed"])/3600," hour to run this piece of code"))
# Out:
# [1] "Thus it takes 0.289250277777778 hour to run this piece of code"

# %% [markdown]
# the function selected the following numbers of most informative variables from the loading vectors for each OMICs data set for each of the two principal components

# %%
tune.omics$choice.keepX
# Out:
# $Proteomics_CW
# [1] 1
#
# $Transcriptomics
# [1] 1
#
# $Transcriptomics_CW
# [1] 2
#
# $Phenomics
# [1] 1
#
# $Metabolomics
# [1] 1

# %% [markdown]
# Now let us perform the final sPLS-DA modelling and display PCA plots and loadings. Genetic variation data is notoriously difficult to handle by traditional statistical approaches that assume normality, therefore PLS (as well as many statistical other tools) has unfortunately problems working with this type of data.

# %%
list.keepX=list("Proteomics_CW"=tune.omics$choice.keepX$Proteomics_CW,"Transcriptomics_CW"=tune.omics$choice.keepX$Transcriptomics_CW,"Transcriptomics"=tune.omics$choice.keepX$Transcriptomics,"Phenomics"=tune.omics$choice.keepX$Phenomics,"Metabolomics"=tune.omics$choice.keepX$Metabolomics)
res=block.splsda(X=data,Y=Temperature,ncomp=2,keepX=list.keepX,design=design,near.zero.var=FALSE)
# Out:
# Design matrix has changed to include Y; each block will be
#             linked to Y.

# %%
selectVar(res,block='Metabolomics',comp=1)$Metabolomics$name
# Out:
# [1] "Pectin_linearity"

# %%
plotIndiv(res,legend=TRUE,title="Stem Omics",ellipse=FALSE,ind.names=FALSE,cex=2)
# Out:
# plot without title

# %% [markdown]
# Here we can visualize the samples for the 5
# OMICs using their features selected via the integration procedure. each Temperature sample seem to be clearly separated for all omics we can say maybe the only factors that affects the rosettes apearence is temperature

# %% [markdown]
# here we can see the clustering in each block  based on the Temperature we can say that in transcriptomics, transcriptomics_cw and proteomics the cluster are distiguishable meaning that the Temperature affects the genetic composition of the stem and the outside appearence also

# %%
plotLoadings(res,comp=1,contrib='max',method='mean')
# Out:
# Plot with title “Contribution on comp 1
# Block 'Phenomics'”
# Plot with title “Contribution on comp 1
# Block 'Metabolomics'”

# %%
plotLoadings(res,comp=2,contrib='max',method='mean')
# Out:
# Plot with title “Contribution on comp 2
# Block 'Phenomics'”
# Plot with title “Contribution on comp 2
# Block 'Metabolomics'”

# %% [markdown]
# Loading plots for all of our 5 blocks data to discriminate Temperature. Colours indicate the Temperature in which the median is maximum for each variable in each block we use it the 2 most variate componenets

# %% [markdown]
# Now, we will diplay the data points using PCA principal components from individual OMICs. This can be an informative way to to visualise correlation between components from different data sets. In our case TRANSCRIPTOMICS AND TRANSCRIPTOMICS_CW OMICs seem to have the strongest correlation and there's a substantial amount of correlation between both TRANCRIPTOMICS and PROTEOMICS_CW

# %%
plotDiablo(res,ncomp=1)
# Out:
# plot without title

# %% [markdown]
# Graphical representation of the sparse multi-block partial least squares discriminant analysis (MB-PLS-DA) analysis discriminating the rosette samples of Temperature 15 22 The plotDIABLO shows the correlation inside each block pair
# we can also get another look on the clusters and how do they appear in each block of data

# %%
plotArrow(res,ind.names=FALSE,legend=TRUE,title="Rosette Omics Integration")
# Out:
# plot without title

# %% [markdown]
# The Arrow Plot can be viewed as a Consensus Plot between all the OMICs on the sample level, the X and Y coordiantes correspond to common latent variables between the OMICs, i.e. we projected all the OMICs into some common latent space where they loose information about their technological origin and hence can be superimposed onto each other.
#
# Now we will display the so-called Correlation Circle Plot, where the top loadings variables from each of the OMICs are superimposed. Clustering of variables around the poles of the circle implies strong correlation between the variables from different OMICs. Variables on the opposite poles of the correlation circle plot imply strong anti-correlation. While the Arrow Plot serves as a main integrative OMICs visualization on sample level, the Correlation Circle Plots can be considered as a main visualization of OMICs integration on the feature level.

# %%
plotVar(res,var.names=TRUE,style='ggplot2',legend=TRUE,cex=c(3,3,3,3,3),col=c('blue','red2',"darkgreen","darkorange","orange"))
# Out:
# Warning message in plotVar(res, var.names = TRUE, style = "ggplot2", legend = TRUE, :
# “We detected negative correlation between the variates of some blocks, which means that some clusters of variables observed on the correlation circle plot are not necessarily positively correlated.”
# plot without title

# %% [markdown]
# For further visualization of the results of OMICs integration, we will calculate the so-called Circos Plot that diaplays correlations between features from different OMICs dat sets. Please note that here for the Circos Plot, as well as for the Correlation Circle Plot above, the features were selected simultaneously from all the OMICs when performing integration, i.e. they are not equavivalent to those obtained from each individual OMIC separately.

# %%
circosPlot(res,cutoff=0.7,line=FALSE,size.variables=0.5)
# Out:
# Plot with title “”

# %% [markdown]
# Correlation network is another handy way to demostrate correlations between top loadings of the OMICs data sets in a pairwise fashion. Here we can choose a pair of OMICs and make a network comprising most informative features (selected via the integration) from both OMICs. The color of the edges corresponds to the strength of the correlation between the OMICs. One can use a “cutoff” paremeter to display one the the edges above a specified threshold.

# %% [markdown]
# The key insight provided by networks are the sub-networks (or cliques) that can be seen. These clusters often highlight specific structures between variables. The colour of each line indicates the nature of the correlation between each feature.
#
# the clour of each node represents the block or data set or omic
#
# we can do more than 2 at a time but we loose most visibility
#
# some comobos of block doesn't work toghther for exp we cannot do block num 2 with its self (even if we could it would be meaningless) , furthermore some combos lack enough correlation to be displayed

# %%
network(res,blocks=c(1,3),cex.node.name=0.6,color.node=c('blue','red2'),breaks=NULL)
# Out:
# Plot with title “”

# %%
network(res, blocks = c(2,3),color.node = c('darkorchid', 'brown1'), cutoff = 0.4)
# Out:
# Plot with title “”

# %%
network(res,blocks=c(3,4),cex.node.name=0.6,color.node=c('blue','darkorange'),breaks=NULL)
# Out:
# Plot with title “”

# %%
network(res,blocks=c(3,5),cex.node.name=0.6,color.node=c('darkgreen','darkorange'),breaks=NULL)
# Out:
# Plot with title “”

# %% [markdown]
# Finally, the correlation heatmap displays strongly correlated blocks of Our 5 OMICS.

# %% [markdown]
# Here the color of a cell on a heatmap demonstrates abundance of the feature in the sample that are “coordinates” of the cell.
#
#  clustered image map representing the multi-omics profiles for each sample discriminated by the Temperature . The levels of blue (lower values) and red (higher values) denote scaled values for each variable. Note that colors are scaled per line.

# %%
cimDiablo(res,margins=c(5,1))
# Out:
# trimming values to [-3, 3] range for cim visualisation. See 'trim' arg in ?cimDiablo
# Plot with title “Color key”

# %% [markdown]
# ###Predict Temperature from OMICs Integration
